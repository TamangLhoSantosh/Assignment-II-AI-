# %%
from google.colab import drive # mounts the google drive for a new notebook 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load the 2 npy files created by the process_yale_images.ipynb 
from numpy import load
import numpy as np
path = '/content/drive/My Drive/Tr0'
# load array
y = load(path + 'yaleExtB_target.npy')
X = load(path + 'yaleExtB_data.npy')

# %%
from sklearn.model_selection import train_test_split # loads functions from the ML library sklearn 
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier

# %%
# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=26)

# %%
# PCA 
nof_prin_components = 200  # PARAMETER for optimisation in expereiments
pca = PCA(n_components=nof_prin_components, whiten=True, random_state=26).fit(X_train)
# applies PCA to the train and test images to calculate the principal components
X_pca = pca.transform(X)
X_train_pca = pca.transform(X_train) 
X_test_pca = pca.transform(X_test)

# %% [markdown]
# [Documentation of ML sklearn library](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier)

# %%
# delcaaring error to make a graph
accs = list()
nohns = list()

# %%
# train a neural network
nohn = 200 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca) # reoognises the test images 
# print(classification_report(y_test, y_pred)) # the recognition accuracy

from sklearn import metrics # to show the accuracy of the classifier

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.86

# %%
# Increasing the number of neurons to test
nohn = 250
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.86

# %%
# Trainig the neural network with increased number of hidden neurons
nohn = 300 # nof hidden neurons
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8911111111111111

# %%
# As the accuracy decreased decreasing the number of hidden neurons
nohn = 350
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8622222222222222

# %%
# As the accuracy increased again increasing the number of hidden neurons
nohn = 400
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8755555555555555

# %%
# As the accuracy increased again increasing the number of hidden neurons
nohn = 450
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9044444444444445

# %%
# Now let's plot the errors
from matplotlib import pyplot as plt

plt.plot(nohns, accs, 'ro')
plt.xlabel('Number of hidden nodes' + u"\u2192")
plt.ylabel('Accuracy' + u"\u2192")
plt.title('Accuracy of SGD Solver')
plt.show()

# %%
# Reinitializing for other experiments
accs = list()
nohns = list()

# %%
# train a neural network
nohn = 200 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8111111111111111

# %%
# Increasing the number of neurons to test
nohn = 250
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.7844444444444445

# %%
# Still increasing the number of neurons to test
nohn = 300
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8733333333333333

# %%
# As the accuracy increased the neurons are increased
nohn = 350
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8577777777777778

# %%
# Increasing the number of neurons
nohn = 400
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8777777777777778

# %%
# Increasing the number of neurons
nohn = 500
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='sgd', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8088888888888889

# %%
# Plotting the accuracy vs number of hidden neurons

plt.plot(nohns, accs, 'ro')
plt.xlabel('Number of hidden nodes' + u"\u2192")
plt.ylabel('Accuracy' + u"\u2192")
plt.title('Accuracy of SGD Solver')
plt.show()

# %%
# Reinitializing for other experiments
accs = list()
nohns = list()

# %%
# train a neural network
nohn = 200 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9422222222222222

# %%
# Increasing the number of hidden neurons
nohn = 250 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9444444444444444

# %%
# Increasing the number of hidden neurons again
nohn = 300 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9533333333333334

# %%
# Increasing the number of hidden neurons again
nohn = 350 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9555555555555556

# %%
# Increasing the number of hidden neurons again
nohn = 450 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='tanh',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9644444444444444

# %%
plt.plot(nohns, accs, 'ro')
plt.xlabel('Number of hidden nodes' + u"\u2192")
plt.ylabel('Accuracy' + u"\u2192")
plt.title('Accuracy of lbfgs Solver')
plt.show()

# %%
# Reinitializing for other experiments
accs = list()
nohns = list()

# %%
# train a neural network
nohn = 200 # nof hidden neurons
nohns.append(nohn)

# print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.94

# %%
# Increasing the number of neurons to test
nohn = 250
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.94

# %%
# Still increasing the number of neurons to test
nohn = 300
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9488888888888889

# %%
# As the accuracy increased the neurons are increased
nohn = 350
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9555555555555556

# %%
# Increasing the number of neurons
nohn = 400
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9444444444444444

# %%
# Increasing the number of neurons
nohn = 450
nohns.append(nohn)

clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='lbfgs', activation='relu',
                    batch_size=256, verbose=False, early_stopping=True, random_state=26).fit(X_train_pca, y_train)

# %%
y_pred = clf.predict(X_test_pca)

acc = metrics.accuracy_score(y_test, y_pred)
accs.append(acc)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9355555555555556

# %%
# Plotting the accuracy vs number of hidden neurons

plt.plot(nohns, accs, 'ro')
plt.xlabel('Number of hidden nodes' + u"\u2192")
plt.ylabel('Accuracy' + u"\u2192")
plt.title('Accuracy of SGD Solver')
plt.show()
